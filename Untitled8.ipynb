# %% [markdown]
# <a href="https://colab.research.google.com/github/saxonmahar/Deeplearning/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import BernoulliRBM
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy.special import expit as sigmoid

# %%
print("Loading MNIST...")
X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)
# Out:
# Loading MNIST...

# %%
X = MinMaxScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)

# %%
rbm = BernoulliRBM(n_components=64, learning_rate=0.06, batch_size=10, n_iter=10, random_state=42, verbose=True)
rbm.fit(X_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -133.85, time = 0.50s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -121.43, time = 0.63s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -112.57, time = 0.60s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -107.60, time = 0.61s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -103.79, time = 0.61s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -101.78, time = 0.62s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -99.29, time = 0.80s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -97.25, time = 0.87s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -96.34, time = 0.60s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -96.13, time = 0.60s
# BernoulliRBM(learning_rate=0.06, n_components=64, random_state=42, verbose=True)

# %%
def manual_reconstruct(rbm, data):
    hidden_activations = sigmoid(np.dot(data, rbm.components_.T) + rbm.intercept_hidden_)
    visible_reconstruction = sigmoid(np.dot(hidden_activations, rbm.components_) + rbm.intercept_visible_)

    return visible_reconstruction

# %%
samples = X_test[:10]
reconstructed = manual_reconstruct(rbm, samples)

# %%
def plot_images(original, reconstructed, n=10):
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Original image
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original[i].reshape(28, 28), cmap='gray')
        plt.title("Original")
        plt.axis("off")

        # Reconstructed image
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructed[i].reshape(28, 28), cmap='gray')
        plt.title("Reconstructed")
        plt.axis("off")
    plt.show()

plot_images(samples, reconstructed)
